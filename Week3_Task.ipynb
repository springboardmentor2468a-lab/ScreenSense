# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('final_screen (1).xls')

# %%
data.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural            Age_Band Week_Type  \
# 0  Poor Sleep, Eye Strain          Urban    Mid_Teen (14-16)   Weekday
# 1              Poor Sleep          Urban  Early_Teen (11-13)   Weekend
# ...

# %%
#Numerical
plt.figure()
plt.hist(data["Avg_Daily_Screen_Time_hr"], bins=5)
plt.xlabel("Screen Time (Hours)")
plt.ylabel("Frequency")
plt.title("Histogram of Screen Time")
plt.show()

plt.figure()
plt.boxplot(data["Avg_Daily_Screen_Time_hr"])
plt.title("Box Plot of Screen Time")
plt.show()

plt.figure()
sns.kdeplot(data["Avg_Daily_Screen_Time_hr"], fill=True)
plt.title("Density Plot of Screen Time")
plt.show()

# %%
plt.figure()
plt.hist(data["Age"], bins=5)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age")
plt.show()

plt.figure()
plt.boxplot(data["Age"])
plt.title("Box Plot of Age")
plt.show()

plt.figure()
sns.kdeplot(data["Age"], fill=True)
plt.title("Density Plot of Age")
plt.show()

# %%
plt.figure()
plt.hist(data["Educational_to_Recreational_Ratio"], bins=5)
plt.xlabel("Educational_to_Recreational_Ratio")
plt.ylabel("Frequency")
plt.title("Histogram of Educational_to_Recreational_Ratio")
plt.show()

plt.figure()
plt.boxplot(data["Educational_to_Recreational_Ratio"])
plt.title("Box Plot of Educational_to_Recreational_Ratio")
plt.show()

plt.figure()
sns.kdeplot(data["Educational_to_Recreational_Ratio"], fill=True)
plt.title("Density Plot of Educational_to_Recreational_Ratio")
plt.show()

# %%
#Categorical 
plt.figure()
data["Primary_Device"].value_counts().plot(kind="bar")
plt.xlabel("Device Type")
plt.ylabel("Count")
plt.title("Bar Chart of Device Type")
plt.show()

plt.figure()
data["Primary_Device"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of Device Type")
plt.show()

# %%
plt.figure()
data["Age_Band"].value_counts().plot(kind="bar")
plt.xlabel("Age Band")
plt.ylabel("Count")
plt.title("Bar Chart of Age Band")
plt.show()

plt.figure()
data["Age_Band"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of Age Band")
plt.show()

# %%
plt.figure()
data["Health_Severity"].value_counts().plot(kind="bar")
plt.xlabel("Health risk")
plt.ylabel("Count")
plt.title("Bar Chart of Health risk")
plt.show()

plt.figure()
data["Health_Severity"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of Health risk")
plt.show()

# %%
# Split into list

df = data.copy()
df["Health_Impacts"] = df["Health_Impacts"].str.split(",")

df["Health_Impacts"] = df["Health_Impacts"].apply(
    lambda x: [i.strip() for i in x]
)

dat = df.explode("Health_Impacts")

# %%
plt.figure()
dat["Health_Impacts"].value_counts().plot(kind="bar")
plt.xlabel("Health risk")
plt.ylabel("Count")
plt.title("Bar Chart of Health problems")
plt.show()

plt.figure()
dat["Health_Impacts"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of health problems")
plt.show()

# %%
plt.figure()
dat["Urban_or_Rural"].value_counts().plot(kind="bar")
plt.xlabel("Place")
plt.ylabel("Count")
plt.title("Bar Chart of place")
plt.show()

plt.figure()
dat["Urban_or_Rural"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of place")
plt.show()

# %%
plt.figure()
dat["Gender"].value_counts().plot(kind="bar")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Bar Chart of gender")
plt.show()

plt.figure()
dat["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of gender")
plt.show()


counts = data["Gender"].value_counts()

plt.pie(counts, labels=counts.index, autopct="%1.1f%%")
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Donut Chart of Gender")
plt.show()

# %%
plt.figure()
dat["Screen_Time_Range"].value_counts().plot(kind="bar")
plt.xlabel("screen time")
plt.ylabel("Count")
plt.title("Bar Chart of screen time")
plt.show()

plt.figure()
dat["Screen_Time_Range"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Pie Chart of screen time")
plt.show()

# %%
#Numeric vs Numeric 
plt.scatter(data["Age"], data["Avg_Daily_Screen_Time_hr"])
plt.xlabel("Age")
plt.ylabel("Screen time")
plt.title("Age vs Screen Time")
plt.show()

plt.plot(data["Age"], data["Avg_Daily_Screen_Time_hr"])
plt.xlabel("Age")
plt.ylabel("Screen time")
plt.show()

import seaborn as sns
sns.regplot(x="Age", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()



corr = data[["Age", "Avg_Daily_Screen_Time_hr"]].corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
plt.scatter(data["Age"], data["Educational_to_Recreational_Ratio"])
plt.xlabel("Age")
plt.ylabel("Educational_to_Recreational_Ratio")
plt.title("Age vs Educational_to_Recreational_Ratio")
plt.show()

plt.plot(data["Age"], data["Educational_to_Recreational_Ratio"])
plt.xlabel("Age")
plt.ylabel("Screen time")
plt.show()

import seaborn as sns
sns.regplot(x="Age", y="Educational_to_Recreational_Ratio", data=data)
plt.show()



corr = data[["Age", "Educational_to_Recreational_Ratio"]].corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
#Categorical vs categorical
pd.crosstab(data["Gender"], data["Primary_Device"]).plot(kind="bar")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender vs Device Type")
plt.show()

pd.crosstab(data["Gender"], data["Primary_Device"]).plot(kind="bar", stacked=True)
plt.show()

ct = pd.crosstab(data["Gender"], data["Primary_Device"])
sns.heatmap(ct, annot=True, cmap="Blues")
plt.show()

# %%
pd.crosstab(data["Urban_or_Rural"], data["Primary_Device"]).plot(kind="bar")
plt.xlabel("Place")
plt.ylabel("Count")
plt.title("place vs Device Type")
plt.show()

pd.crosstab(data["Urban_or_Rural"], data["Primary_Device"]).plot(kind="bar", stacked=True)
plt.show()

ct = pd.crosstab(data["Urban_or_Rural"], data["Primary_Device"])
sns.heatmap(ct, annot=True, cmap="Blues")
plt.show()

# %%
pd.crosstab(dat["Primary_Device"], dat["Health_Impacts"]).plot(kind="bar")
plt.xlabel("Place")
plt.ylabel("Count")
plt.title("Health impacts vs Device Type")
plt.show()

pd.crosstab(dat["Health_Impacts"], dat["Primary_Device"]).plot(kind="bar", stacked=True)
plt.show()

ct = pd.crosstab(dat["Health_Impacts"], dat["Primary_Device"])
sns.heatmap(ct, annot=True, cmap="Blues")
plt.show()

# %%
pd.crosstab(dat["Age_Band"], dat["Primary_Device"]).plot(kind="bar")
plt.xlabel("Age band")
plt.ylabel("count")
plt.title("age band vs Device Type")
plt.show()

pd.crosstab(dat["Age_Band"], dat["Primary_Device"]).plot(kind="bar", stacked=True)
plt.show()

ct = pd.crosstab(dat["Age_Band"], dat["Primary_Device"])
sns.heatmap(ct, annot=True, cmap="Blues")
plt.show()

# %%
pd.crosstab(dat["Primary_Device"], dat["Week_Type"]).plot(kind="bar")
plt.xlabel("Device")
plt.ylabel("Count")
plt.title("Primary device vs week type")
plt.show()

pd.crosstab(dat["Primary_Device"], dat["Week_Type"]).plot(kind="bar", stacked=True)
plt.show()

ct = pd.crosstab(dat["Primary_Device"], dat["Week_Type"])
sns.heatmap(ct, annot=True, cmap="Blues")
plt.show()

# %%
pd.crosstab(dat["Age_Band"], dat["Screen_Time_Range"]).plot(kind="bar")
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Health impacts vs Device Type")
plt.show()

pd.crosstab(dat["Age_Band"], dat["Screen_Time_Range"]).plot(kind="bar", stacked=True)
plt.show()

ct = pd.crosstab(dat["Age_Band"], dat["Screen_Time_Range"])
sns.heatmap(ct, annot=True, cmap="Blues")
plt.show()

# %%
#Numerical vs categorical 

sns.violinplot(x="Gender", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()

sns.boxplot(x="Gender", y="Avg_Daily_Screen_Time_hr", data=data)
plt.title("Avg_Daily_Screen_Time_hr vs Gender")
plt.show()

sns.stripplot(x="Gender", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()

sns.barplot(x="Gender", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()

# %%
sns.violinplot(x="Age_Band", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()

sns.boxplot(x="Age_Band", y="Avg_Daily_Screen_Time_hr", data=data)
plt.title("Avg_Daily_Screen_Time_hr vs Age_Band")
plt.show()

sns.stripplot(x="Age_Band", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()

sns.barplot(x="Age_Band", y="Avg_Daily_Screen_Time_hr", data=data)
plt.show()
