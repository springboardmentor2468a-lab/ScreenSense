# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv("Indian_Kids_Screen_Time.csv")

# %%
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# 2                           True                               0.32
# 3                          False                               0.39
# 4                           True                               0.49
# ...                          ...                                ...
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 0              Poor Sleep, Eye Strain          Urban
# 1                          Poor Sleep          Urban
# 2                          Poor Sleep          Urban
# 3                                 NaN          Urban
# 4                 Poor Sleep, Anxiety          Urban
# ...                               ...            ...
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# 9709  Poor Sleep, Eye Strain, Anxiety          Rural
# 9710                       Poor Sleep          Urban
# 9711                          Anxiety          Urban
#
# [9712 rows x 8 columns]

# %% [markdown]
# Basic overview

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   str
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   str
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   str
#  7   Urban_or_Rural                     9712 non-null   str
# dtypes: bool(1), float64(2), int64(1), str(4)
# memory usage: 804.7 KB
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %% [markdown]
# Check/handle missing,null values

# %%
df.isnull().sum() 
df['Health_Impacts'] = df['Health_Impacts'].fillna("Unknown")

# %%
df.describe(include=['object', 'string'])
# Out:
#        Gender Primary_Device Health_Impacts Urban_or_Rural
# count    9712           9712           9712           9712
# unique      2              4             16              2
# top      Male     Smartphone        Unknown          Urban
# freq     4942           4568           3218           6851

# %%
df.describe(include='all')
# Out:
#                 Age Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# count   9712.000000   9712               9712.000000           9712
# unique          NaN      2                       NaN              4
# top             NaN   Male                       NaN     Smartphone
# freq            NaN   4942                       NaN           4568
# mean      12.979201    NaN                  4.352837            NaN
# std        3.162437    NaN                  1.718232            NaN
# min        8.000000    NaN                  0.000000            NaN
# 25%       10.000000    NaN                  3.410000            NaN
# 50%       13.000000    NaN                  4.440000            NaN
# 75%       16.000000    NaN                  5.380000            NaN
# max       18.000000    NaN                 13.890000            NaN
#
#        Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# count                        9712                        9712.000000
# unique                          2                                NaN
# top                          True                                NaN
# freq                         8301                                NaN
# mean                          NaN                           0.427226
# std                           NaN                           0.073221
# min                           NaN                           0.300000
# 25%                           NaN                           0.370000
# 50%                           NaN                           0.430000
# 75%                           NaN                           0.480000
# max                           NaN                           0.600000
#
#        Health_Impacts Urban_or_Rural
# count            9712           9712
# unique             16              2
# top           Unknown          Urban
# freq             3218           6851
# mean              NaN            NaN
# std               NaN            NaN
# min               NaN            NaN
# 25%               NaN            NaN
# 50%               NaN            NaN
# 75%               NaN            NaN
# max               NaN            NaN

# %% [markdown]
# Create Age Groups

# %%
df['Health_Impacts'].unique()
# Out:
# <ArrowStringArray>
# [                       'Poor Sleep, Eye Strain',
#                                     'Poor Sleep',
#                                        'Unknown',
#                            'Poor Sleep, Anxiety',
#                       'Poor Sleep, Obesity Risk',
#                                     'Eye Strain',
#                                   'Obesity Risk',
#                                        'Anxiety',
#              'Poor Sleep, Anxiety, Obesity Risk',
#                       'Eye Strain, Obesity Risk',
#              'Eye Strain, Anxiety, Obesity Risk',
#                          'Anxiety, Obesity Risk',
#           'Poor Sleep, Eye Strain, Obesity Risk',
#                'Poor Sleep, Eye Strain, Anxiety',
#  'Poor Sleep, Eye Strain, Anxiety, Obesity Risk',
#                            'Eye Strain, Anxiety']
# Length: 16, dtype: str

# %%
bins = [0, 6, 10, 14, 18]
labels = ['0-6', '7-10', '11-14', '15-18']

df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df[['Age', 'Age_Group']].head()
# Out:
#    Age Age_Group
# 0   14     11-14
# 1   11     11-14
# 2   18     15-18
# 3   15     15-18
# 4   12     11-14

# %% [markdown]
# EDA Visualizations

# %% [markdown]
# 1. Screen time distribution

# %%
sns.histplot(df['Avg_Daily_Screen_Time_hr'], bins=20)
plt.title("Distribution of Daily Screen Time")
plt.show()

# %% [markdown]
# 2. Screen time by gender

# %%
sns.barplot(x='Gender', y='Avg_Daily_Screen_Time_hr', data=df)
plt.title("Screen Time by Gender")
plt.show()

# %% [markdown]
# 3.Device usage

# %%
sns.countplot(x='Primary_Device', data=df)
plt.title("Primary Device Used by Kids")
plt.show()

# %% [markdown]
# 4.Screen time by age group

# %%
sns.boxplot(x='Age_Group', y='Avg_Daily_Screen_Time_hr', data=df)
plt.title("Screen Time by Age Group")
plt.show()

# %% [markdown]
# 5. Urban vs Rural screen time

# %%
sns.barplot(x='Urban_or_Rural', y='Avg_Daily_Screen_Time_hr', data=df)
plt.title("Screen Time: Urban vs Rural")
plt.show()

# %% [markdown]
# 6. Exceeded recommended limit

# %%
sns.countplot(x='Exceeded_Recommended_Limit', data=df)
plt.title("Kids Exceeding Recommended Screen Time")
plt.show()

# %% [markdown]
# 7. Correlation heatmap

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Avg_Daily_Screen_Time_hr', 'Primary_Device',
#        'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio',
#        'Health_Impacts', 'Urban_or_Rural', 'Age_Group'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Age                                     int64
# Gender                                    str
# Avg_Daily_Screen_Time_hr              float64
# Primary_Device                            str
# Exceeded_Recommended_Limit               bool
# Educational_to_Recreational_Ratio     float64
# Health_Impacts                            str
# Urban_or_Rural                            str
# Age_Group                            category
# dtype: object

# %%
df.shape
# Out:
# (9712, 9)

# %%
df['Exceeded_Recommended_Limit'].dtype
# Out:
# dtype('bool')

# %%
df['Exceeded_Recommended_Limit'] = df['Exceeded_Recommended_Limit'].map({True: "Yes", False: "No"})

# %%
df['Exceeded_Recommended_Limit'].unique()
# Out:
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
df['Gender'] = df['Gender'].str.strip().str.title()
df['Primary_Device'] = df['Primary_Device'].str.strip().str.title()
df['Urban_or_Rural'] = df['Urban_or_Rural'].str.strip().str.title()
df['Health_Impacts'] = df['Health_Impacts'].str.strip().str.title()

# %% [markdown]
# Derived Fields

# %%
bins = [6, 10, 14, 17]
labels = ['6-10', '11-14', '15-17']

df['Age_Band'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
sns.countplot(x='Age_Band', data=df)
plt.title("Distribution of Age Bands")
plt.show()

# %%
df['Educational_to_Recreational_Ratio'].describe()
# Out:
# count    9712.000000
# mean        0.427226
# std         0.073221
# min         0.300000
# 25%         0.370000
# 50%         0.430000
# 75%         0.480000
# max         0.600000
# Name: Educational_to_Recreational_Ratio, dtype: float64

# %%
df['Educational_to_Recreational_Ratio'].max()
# Out:
# np.float64(0.6)

# %%
health_counts = df['Health_Impacts'].value_counts().head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=health_counts.index, y=health_counts.values)
plt.xticks(rotation=45)
plt.title("Top Health Impacts")
plt.show()

# %%
# Age Band
df['Age_Band'] = pd.cut(df['Age'],
                        bins=[5,9,12,15,18],
                        labels=['6-9','10-12','13-15','16-18'])

# Usage Level
df['Usage_Level'] = pd.cut(df['Avg_Daily_Screen_Time_hr'],
                           bins=[0,2,4,6,10],
                           labels=['Low','Moderate','High','Extreme'])

# Device Type Category
df['Device_Type_Category'] = df['Primary_Device'].apply(
    lambda x: 'Portable' if x in ['Mobile','Tablet','Laptop'] else 'Wall-Mounted'
)

# %%
df['Usage_Level'] = pd.cut(
    df['Educational_to_Recreational_Ratio'],
    bins=[0.3, 0.4, 0.5, 0.6],
    labels=['Low Educational', 'Moderate Educational', 'High Educational']
)

# %%
df['Usage_Level'].value_counts(normalize=True) * 100
# Out:
# Usage_Level
# Moderate Educational    48.331234
# Low Educational         38.192695
# High Educational        13.476071
# Name: proportion, dtype: float64

# %%
df['Educational_to_Recreational_Ratio'].describe()
# Out:
# count    9712.000000
# mean        0.427226
# std         0.073221
# min         0.300000
# 25%         0.370000
# 50%         0.430000
# 75%         0.480000
# max         0.600000
# Name: Educational_to_Recreational_Ratio, dtype: float64

# %%
device_share = df['Primary_Device'].value_counts(normalize=True) * 100
print(device_share) # device share
# Out:
# Primary_Device
# Smartphone    47.034596
# Tv            25.607496
# Laptop        14.754942
# Tablet        12.602965
# Name: proportion, dtype: float64

# %%
# Create Screen Time Category
df['Screen_Time_Category'] = pd.cut(
    df['Avg_Daily_Screen_Time_hr'],
    bins=[0,2,4,10],
    labels=['Low (0-2h)','Moderate (2-4h)','High (4h+)']
)
df[['Avg_Daily_Screen_Time_hr','Screen_Time_Category']].head()
# Out:
#    Avg_Daily_Screen_Time_hr Screen_Time_Category
# 0                      3.99      Moderate (2-4h)
# 1                      4.61           High (4h+)
# 2                      3.73      Moderate (2-4h)
# 3                      1.21           Low (0-2h)
# 4                      5.89           High (4h+)

# %% [markdown]
# # Univariant and Bivariant Analysis

# %% [markdown]
# #univariant

# %% [markdown]
# 1.Age (Numerical)

# %%
#histogram (univariant)
sns.histplot(df['Age'], bins=12, color='#3498db')
plt.title("Age Distribution")
plt.show()

# %%
#boxplot
sns.boxplot(x=df['Age'], color='#5dade2')
plt.title("Age Boxplot")
plt.show()

# %% [markdown]
# #Bivariant
#
# #Age vs Screen Time (Numerical vs Numerical)

# %%
sns.scatterplot(x='Age',
                y='Avg_Daily_Screen_Time_hr',
                data=df,
                color='#2e86c1')
plt.title("Age vs Screen Time")
plt.show()

# %% [markdown]
# 2.Gender (Categorical)

# %%
#univariant
gender_counts = df['Gender'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(gender_counts,
        labels=gender_counts.index,
        autopct='%1.1f%%',
        colors=['#3498db', '#e74c3c'],
        startangle=90)
plt.title("Gender Distribution")
plt.show()

# %%
#Gender vs screen time (Bivariant)
sns.barplot(x='Gender',
            y='Avg_Daily_Screen_Time_hr',
            data=df,
            hue='Gender',
            palette=['#3498db', '#e74c3c'],
            legend=False)
plt.title("Screen Time by Gender")
plt.show()

# %% [markdown]
# 3.Avg_Daily_Screen_Time_hr (Numerical)

# %%
#univariant
sns.histplot(df['Avg_Daily_Screen_Time_hr'], bins=20, color='#e67e22')
plt.title("Screen Time Distribution")
plt.show()

# %%
#screen time vs device (Bivariant)
sns.boxplot(
    x='Primary_Device',
    y='Avg_Daily_Screen_Time_hr',
    hue='Primary_Device',      
    data=df,
    palette='Set2',
    legend=False               
)

plt.xticks(rotation=45)
plt.title("Screen Time by Device")
plt.show()

# %% [markdown]
# 4.Primary_Device (Categorical)

# %%
#univariant
sns.countplot(
    x='Primary_Device',
    hue='Primary_Device',   
    data=df,
    palette='Set3',
    legend=False           
)

plt.xticks(rotation=45)
plt.title("Device Distribution")
plt.show()

# %%
#device vs exceed limit (Bivariant)
pd.crosstab(df['Primary_Device'],
            df['Exceeded_Recommended_Limit'])
# Out:
# Exceeded_Recommended_Limit   No   Yes
# Primary_Device
# Laptop                      158  1275
# Smartphone                  619  3949
# Tablet                      232   992
# Tv                          402  2085

# %% [markdown]
# 5.Educational_to_Recreational_Ratio (Numerical)

# %%
#univariant
sns.histplot(df['Educational_to_Recreational_Ratio'],
             bins=15,
             color='#1abc9c')
plt.title("Educational to Recreational Ratio")
plt.show()

# %%
#ratio vs screen time (bivariant)
sns.scatterplot(x='Educational_to_Recreational_Ratio',
                y='Avg_Daily_Screen_Time_hr',
                data=df,
                color='#16a085')
plt.title("Ratio vs Screen Time")
plt.show()

# %% [markdown]
# 6.Exceeded_Recommended_Limit (Categorical / Boolean)

# %%
#univariant
limit_counts = df['Exceeded_Recommended_Limit'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(limit_counts,
        labels=limit_counts.index,
        autopct='%1.1f%%',
        colors=['#2ecc71', '#e74c3c'],
        startangle=90)
plt.title("Exceeded Recommended Limit")
plt.show()

# %% [markdown]
# Exceeded Limit vs Device Category

# %% [markdown]
# 7.Health_Impacts (Categorical)

# %%
#univariant
sns.countplot(
    x='Health_Impacts',
    hue='Health_Impacts',   # required when using palette
    data=df,
    palette='Paired',
    legend=False            # removes duplicate legend
)

plt.xticks(rotation=45)
plt.title("Health Impacts Distribution")
plt.show()

# %%
#Health Impact vs Screen Time (bivariant)
sns.countplot(
    x='Health_Impacts',
    data=df,
    color='#e74c3c'
)

plt.xticks(rotation=45)
plt.title("Health Impacts Distribution")
plt.show()

# %% [markdown]
# 8.Urban_or_Rural (Categorical)

# %%
location_counts = df['Urban_or_Rural'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(location_counts,
        labels=location_counts.index,
        autopct='%1.1f%%',
        colors=['#1abc9c', '#34495e'],
        startangle=90)
plt.title("Urban vs Rural Distribution")
plt.show() #univariant

# %%
sns.barplot(x='Urban_or_Rural',
            y='Avg_Daily_Screen_Time_hr',
            data=df)
plt.show() #location vs screen time (bivariant)

# %% [markdown]
# Derived Columns

# %%
#Age_Band (Categorical)
sns.countplot(
    x='Age_Band',
    hue='Age_Band',      
    data=df,
    palette='coolwarm',
    legend=False         
)

plt.title("Age Band Distribution")
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Avg_Daily_Screen_Time_hr', 'Primary_Device',
#        'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio',
#        'Health_Impacts', 'Urban_or_Rural', 'Age_Group', 'Age_Band',
#        'Usage_Level', 'Device_Type_Category', 'Screen_Time_Category'],
#       dtype='str')

# %%
df['Device_Type_Category'] = df['Primary_Device'].apply(
    lambda x: 'Portable' if x in ['Mobile', 'Tablet', 'Laptop'] else 'Wall-Mounted'
)

# %%
#Device_Type_Category
device_counts = df['Device_Type_Category'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(device_counts,
        labels=device_counts.index,
        autopct='%1.1f%%',
        pctdistance=0.75,   # moves percentage outward
        colors=['#9b59b6', '#3498db'],
        startangle=90)

# create donut hole
centre_circle = plt.Circle((0,0), 0.55, fc='white')
plt.gca().add_artist(centre_circle)

plt.title("Device Type Category Share")

plt.show()

# %%
#Usage level
usage_counts = df['Usage_Level'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    usage_counts,
    labels=usage_counts.index,
    autopct='%1.1f%%',
    pctdistance=0.75,  # moves percentage text outward
    colors=['#2ecc71', '#f1c40f', '#e67e22', '#e74c3c'],
    startangle=90,
    textprops={'weight':'bold'}
)

# Create donut hole
centre_circle = plt.Circle((0,0), 0.55, fc='white')
plt.gca().add_artist(centre_circle)

plt.title("Usage Level Distribution")

plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# #Unvariant Analysis
# 1. Age Distribution
# Most children in the dataset fall within the middle age groups, meaning the data mainly represents school-age students. Younger and older age groups appear less frequently.
#
# 2. Screen Time Distribution
# Most children spend a moderate amount of time on screens daily, while only a small number of children have extremely high screen usage.
#
# 3. Gender Distribution
# The dataset contains a fairly balanced representation of male and female participants.
#
# 4. Primary Device Distribution
# Portable devices such as mobile phones and tablets appear to be the most commonly used devices among children compared to stationary devices.
#
# 5. Educational to Recreational Ratio
# The screen usage pattern suggests that children generally use screens more for recreational purposes than for educational activities.
#
# 6. Exceeded Recommended Limit
# A noticeable portion of children exceed the recommended daily screen time limit, indicating potential concerns regarding excessive screen exposure.
#
# 7. Health Impacts Distribution
# Common health issues related to screen usage include eye strain, headaches, and sleep disturbances.
#
# 8. Urban vs Rural Distribution
# The dataset includes children from both urban and rural areas, allowing comparison between different living environments.
#
# 9. Age Band Distribution
# Age bands categorize children into developmental stages, helping to analyze screen habits across different age groups.
#
# 10. Device Type Category
# Portable devices account for the majority of screen usage, suggesting that handheld devices are more accessible and frequently used by children.
#
# 11. Usage Level Distribution
# Most children fall into moderate or high screen usage categories, while fewer children belong to the low usage group.

# %% [markdown]
# # Bivariant Analysis
# 1. Age vs Screen Time
# Screen time tends to increase slightly as age increases, suggesting that older children spend more time using digital devices.
#
# 2. Gender vs Screen Time
# Comparison between genders shows potential differences in average screen time usage patterns.
#
# 3. Device vs Screen Time
# Portable devices are often associated with higher screen time usage due to their convenience and accessibility.
#
# 4. Urban vs Screen Time
# Children living in urban areas may have higher screen exposure compared to rural children because of greater access to technology and internet connectivity.
#
# 5. Device Type vs Exceeded Limit
# Children using portable devices are more likely to exceed recommended screen time limits.
#
# 6. Age Band vs Usage Level
# Higher age bands tend to show higher levels of screen usage, indicating increased screen dependency as children grow older.
#
# 7. Correlation Matrix
# The correlation matrix highlights relationships between numerical variables such as age, screen time, and educational-to-recreational usage ratio.

# %% [markdown]
# # Univariant visual analysis

# %%
# Distribution of Daily Screen Time
sns.histplot(df['Avg_Daily_Screen_Time_hr'], bins=20, color='#3498db')
plt.title("Distribution of Daily Screen Time")
plt.xlabel("Daily Screen Time (Hours)")
plt.ylabel("Frequency")
plt.show()


# Distribution of Age Bands
sns.countplot(
    x='Age_Band',
    hue='Age_Band',
    data=df,
    palette='coolwarm',
    legend=False
)
plt.title("Distribution of Age Bands")
plt.xlabel("Age Band")
plt.ylabel("Count")
plt.show()


# Distribution of Device Usage
sns.countplot(
    x='Primary_Device',
    hue='Primary_Device',
    data=df,
    palette='Set3',
    legend=False
)
plt.xticks(rotation=45)
plt.title("Distribution of Device Usage")
plt.xlabel("Device Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Bivariant visual analysis

# %%
#Screen Time by Gender (Bar Chart)
sns.barplot(
    x='Gender',
    y='Avg_Daily_Screen_Time_hr',
    hue='Gender',
    data=df,
    palette=['#3498db','#e74c3c'],
    legend=False
)

plt.title("Average Screen Time by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Screen Time (Hours)")
plt.show()

# %%
#Screen Time by Age Band
sns.boxplot(
    x='Age_Band',
    y='Avg_Daily_Screen_Time_hr',
    hue='Age_Band',
    data=df,
    palette='Set2',
    legend=False
)

plt.title("Screen Time Distribution by Age Band")
plt.xlabel("Age Band")
plt.ylabel("Screen Time (Hours)")
plt.show()

# %%
# screen time by location (urban vs rural)
sns.barplot(
    x='Urban_or_Rural',
    y='Avg_Daily_Screen_Time_hr',
    hue='Urban_or_Rural',
    data=df,
    palette=['#1abc9c','#34495e'],
    legend=False
)

plt.title("Average Screen Time by Location")
plt.xlabel("Location Type")
plt.ylabel("Average Screen Time (Hours)")
plt.show()

# %%
#Screen Time Trend Across Age Bands (Line Plot)
avg_screen_age = df.groupby('Age_Band')['Avg_Daily_Screen_Time_hr'].mean()

plt.plot(avg_screen_age.index, avg_screen_age.values, marker='o', color='#9b59b6')

plt.title("Average Screen Time Across Age Bands")
plt.xlabel("Age Band")
plt.ylabel("Average Screen Time (Hours)")
plt.grid(True)
plt.show()

# %% [markdown]
# Device Mix by Gender

# %%
sns.countplot(
    x='Primary_Device',
    hue='Gender',
    data=df,
    palette='Set2'
)

plt.xticks(rotation=45)
plt.title("Device Mix by Gender")
plt.xlabel("Device Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Device Mix by Age Band

# %%
sns.countplot(
    x='Primary_Device',
    hue='Age_Band',
    data=df,
    palette='coolwarm'
)

plt.xticks(rotation=45)
plt.title("Device Usage by Age Band")
plt.xlabel("Device Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Screen Time by Device Type

# %%
sns.boxplot(
    x='Primary_Device',
    y='Avg_Daily_Screen_Time_hr',
    hue='Primary_Device',
    data=df,
    palette='Set3',
    legend=False
)

plt.xticks(rotation=45)
plt.title("Screen Time by Device Type")
plt.show()

# %% [markdown]
# Activity Category vs Screen Time

# %%
sns.boxplot(
    x='Usage_Level',
    y='Avg_Daily_Screen_Time_hr',
    hue='Usage_Level',
    data=df,
    palette='coolwarm',
    legend=False
)

plt.title("Screen Time by Usage Category")
plt.show()

# %% [markdown]
# Screen Time Trend by Age Band (Line Plot)

# %%
avg_age_screen = df.groupby('Age_Band')['Avg_Daily_Screen_Time_hr'].mean()

plt.plot(avg_age_screen.index, avg_age_screen.values, marker='o', color='#9b59b6')

plt.title("Average Screen Time Across Age Bands")
plt.xlabel("Age Band")
plt.ylabel("Average Screen Time (Hours)")
plt.grid(True)
plt.show()

# %% [markdown]
# Device Category vs Exceeded Limit

# %%
ct = pd.crosstab(df['Primary_Device'],
                 df['Exceeded_Recommended_Limit'])

sns.heatmap(ct, annot=True, cmap='Blues')

plt.title("Device Type vs Exceeded Screen Time Limit")
plt.show()

# %% [markdown]
# Age Band vs Usage Level

# %%
ct2 = pd.crosstab(df['Age_Band'],
                  df['Usage_Level'])

sns.heatmap(ct2, annot=True, cmap='Reds')

plt.title("Age Band vs Screen Usage Level")
plt.show()
